# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=738c94105367ff81c59e75d297edf2e8

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 1 | ketchikan
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | gumdag
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | winnemucca
# Processing Record 7 of Set 1 | cockburn town
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | kadnikov
# Processing Record 10 of Set 1 | salmo
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | salalah
# Processing Record 13 of Set 1 | itoman
# Processing Record 14 of Set 1 | kumo
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | camrose
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | zhuhai
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | la ronge
# Processing Record 21 of Set 1 | luwingu
# Processing Record 22 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 1 | vestmanna
# Processing Record 24 of Set 1 | jalu
# Processing Record 25 of Set 1 | yulara
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | alofi
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | bowen
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | les cayes
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | mehamn
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | taksimo
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | murcia
# Processing Record 40 of Set 1 | yelovo
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | savalou
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | bitung
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | attock
# Processing Record 1 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 2 | xichang
# Processing Record 3 of Set 2 | viedma
# Processing Record 4 of Set 2 | christchurch
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | krasnoselkup
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | bida
# Processing Record 13 of Set 2 | vitimskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | san cristobal
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | aitape
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | azanka
# Processing Record 20 of Set 2 | mount gambier
# Processing Record 21 of Set 2 | dakar
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | port hardy
# Processing Record 25 of Set 2 | paamiut
# Processing Record 26 of Set 2 | sukpak
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | talaya
# Processing Record 29 of Set 2 | baculin
# Processing Record 30 of Set 2 | college
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | corowa
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | longavi
# Processing Record 35 of Set 2 | keti bandar
# Processing Record 36 of Set 2 | am timan
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | mbini
# Processing Record 40 of Set 2 | visby
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | tongchuan
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 2 | fortuna
# Processing Record 1 of Set 3 | manado
# Processing Record 2 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 3 | yerbogachen
# Processing Record 4 of Set 3 | lasa
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | vila velha
# Processing Record 7 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 3 | gornopravdinsk
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | abu dhabi
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | sao felix do xingu
# Processing Record 13 of Set 3 | clyde river
# Processing Record 14 of Set 3 | hami
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 3 | huarmey
# Processing Record 17 of Set 3 | gorontalo
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 3 | berdigestyakh
# Processing Record 21 of Set 3 | praia da vitoria
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | sampit
# Processing Record 26 of Set 3 | alta floresta
# Processing Record 27 of Set 3 | newport
# Processing Record 28 of Set 3 | lianzhou
# Processing Record 29 of Set 3 | usogorsk
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | gazanjyk
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | araouane
# Processing Record 34 of Set 3 | arlit
# Processing Record 35 of Set 3 | danjiangkou
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | babushkin
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | moncton
# Processing Record 40 of Set 3 | marystown
# Processing Record 41 of Set 3 | yucaipa
# Processing Record 42 of Set 3 | nobeoka
# Processing Record 43 of Set 3 | vaini
# Processing Record 44 of Set 3 | sistranda
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | alice springs
# Processing Record 47 of Set 3 | la palma
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | belyy yar
# Processing Record 50 of Set 3 | barras
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | shenjiamen
# Processing Record 4 of Set 4 | meulaboh
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | svetlyy
# Processing Record 7 of Set 4 | chara
# Processing Record 8 of Set 4 | prince rupert
# Processing Record 9 of Set 4 | acapulco
# Processing Record 10 of Set 4 | kathmandu
# Processing Record 11 of Set 4 | asau
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | fairview
# Processing Record 16 of Set 4 | pacific grove
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 20 of Set 4 | atambua
# Processing Record 21 of Set 4 | saint-francois
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | bonavista
# Processing Record 24 of Set 4 | mapiripan
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | cap malheureux
# Processing Record 27 of Set 4 | andenes
# Processing Record 28 of Set 4 | presidencia roque saenz pena
# Processing Record 29 of Set 4 | singaparna
# Processing Record 30 of Set 4 | nelson bay
# Processing Record 31 of Set 4 | puerto escondido
# Processing Record 32 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 4 | ngunguru
# Processing Record 35 of Set 4 | namatanai
# Processing Record 36 of Set 4 | de aar
# Processing Record 37 of Set 4 | krasnoyarka
# Processing Record 38 of Set 4 | aksu
# Processing Record 39 of Set 4 | prachuap khiri khan
# Processing Record 40 of Set 4 | areosa
# Processing Record 41 of Set 4 | tuy hoa
# Processing Record 42 of Set 4 | deputatskiy
# Processing Record 43 of Set 4 | onverwacht
# Processing Record 44 of Set 4 | astoria
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | avera
# Processing Record 47 of Set 4 | nieves
# Processing Record 48 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 4 | tucurui
# Processing Record 50 of Set 4 | benemerito de las americas
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | tual
# Processing Record 3 of Set 5 | praia
# Processing Record 4 of Set 5 | tessalit
# Processing Record 5 of Set 5 | tallahassee
# Processing Record 6 of Set 5 | ribeira do pombal
# Processing Record 7 of Set 5 | antalaha
# Processing Record 8 of Set 5 | gbarnga
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | akyab
# Processing Record 11 of Set 5 | berbera
# Processing Record 12 of Set 5 | samarai
# Processing Record 13 of Set 5 | alyangula
# Processing Record 14 of Set 5 | agva
# City not found. Skipping...
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | khash
# Processing Record 17 of Set 5 | sulangan
# Processing Record 18 of Set 5 | bubaque
# Processing Record 19 of Set 5 | tambopata
# Processing Record 20 of Set 5 | meiganga
# Processing Record 21 of Set 5 | teya
# Processing Record 22 of Set 5 | sivaki
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | okha
# Processing Record 25 of Set 5 | ambilobe
# Processing Record 26 of Set 5 | ayan
# Processing Record 27 of Set 5 | kenai
# Processing Record 28 of Set 5 | cabedelo
# Processing Record 29 of Set 5 | yellowknife
# Processing Record 30 of Set 5 | awbari
# Processing Record 31 of Set 5 | pangkalanbuun
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | ajaccio
# Processing Record 34 of Set 5 | paita
# Processing Record 35 of Set 5 | hiroshima
# Processing Record 36 of Set 5 | diu
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | mbinga
# Processing Record 40 of Set 5 | cidreira
# Processing Record 41 of Set 5 | ixtapa
# Processing Record 42 of Set 5 | kinsale
# Processing Record 43 of Set 5 | saint-pierre
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | haines junction
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | humberto de campos
# Processing Record 48 of Set 5 | antofagasta
# Processing Record 49 of Set 5 | merced
# Processing Record 50 of Set 5 | omsukchan
# Processing Record 1 of Set 6 | magdagachi
# Processing Record 2 of Set 6 | selaphum
# Processing Record 3 of Set 6 | pedernales
# Processing Record 4 of Set 6 | marsh harbour
# Processing Record 5 of Set 6 | mirnyy
# Processing Record 6 of Set 6 | siocon
# Processing Record 7 of Set 6 | basco
# Processing Record 8 of Set 6 | tura
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | point fortin
# Processing Record 11 of Set 6 | vicuna
# Processing Record 12 of Set 6 | lancaster
# Processing Record 13 of Set 6 | rocha
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | padang
# Processing Record 19 of Set 6 | marquette
# Processing Record 20 of Set 6 | dharur
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | kuching
# Processing Record 23 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 6 | kayerkan
# Processing Record 25 of Set 6 | rosarito
# Processing Record 26 of Set 6 | egvekinot
# Processing Record 27 of Set 6 | xiuyan
# Processing Record 28 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 6 | sao paulo de olivenca
# Processing Record 30 of Set 6 | palmer
# Processing Record 31 of Set 6 | honningsvag
# Processing Record 32 of Set 6 | bereda
# Processing Record 33 of Set 6 | hirado
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | vendome
# Processing Record 36 of Set 6 | port blair
# Processing Record 37 of Set 6 | taunggyi
# Processing Record 38 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 6 | lazaro cardenas
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | laela
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | nemuro
# Processing Record 44 of Set 6 | sagua la grande
# Processing Record 45 of Set 6 | rawson
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | victoria
# Processing Record 48 of Set 6 | mackay
# Processing Record 49 of Set 6 | pangoa
# Processing Record 50 of Set 6 | erenhot
# Processing Record 1 of Set 7 | traverse city
# Processing Record 2 of Set 7 | santa fe
# Processing Record 3 of Set 7 | homer
# Processing Record 4 of Set 7 | beringovskiy
# Processing Record 5 of Set 7 | bonthe
# Processing Record 6 of Set 7 | azare
# Processing Record 7 of Set 7 | pechora
# Processing Record 8 of Set 7 | werda
# Processing Record 9 of Set 7 | flinders
# Processing Record 10 of Set 7 | pedasi
# Processing Record 11 of Set 7 | srednekolymsk
# Processing Record 12 of Set 7 | sorland
# Processing Record 13 of Set 7 | perelyub
# Processing Record 14 of Set 7 | beyneu
# Processing Record 15 of Set 7 | turtas
# Processing Record 16 of Set 7 | boda
# Processing Record 17 of Set 7 | najran
# Processing Record 18 of Set 7 | diffa
# Processing Record 19 of Set 7 | mandera
# Processing Record 20 of Set 7 | kodiak
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | ravar
# Processing Record 23 of Set 7 | husavik
# Processing Record 24 of Set 7 | longyearbyen
# Processing Record 25 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 7 | charlottesville
# Processing Record 27 of Set 7 | tezu
# Processing Record 28 of Set 7 | nioro
# Processing Record 29 of Set 7 | lisakovsk
# Processing Record 30 of Set 7 | svetlogorsk
# Processing Record 31 of Set 7 | san miguel
# Processing Record 32 of Set 7 | maracena
# Processing Record 33 of Set 7 | talnakh
# Processing Record 34 of Set 7 | lavrentiya
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | kaeo
# Processing Record 37 of Set 7 | nyurba
# Processing Record 38 of Set 7 | hofn
# Processing Record 39 of Set 7 | desaguadero
# Processing Record 40 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 7 | sokolo
# Processing Record 42 of Set 7 | sitapur
# Processing Record 43 of Set 7 | griffith
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | samarinda
# Processing Record 46 of Set 7 | enugu
# Processing Record 47 of Set 7 | hirara
# Processing Record 48 of Set 7 | koper
# Processing Record 49 of Set 7 | ullapool
# Processing Record 50 of Set 7 | rio gallegos
# Processing Record 1 of Set 8 | baykit
# Processing Record 2 of Set 8 | umm kaddadah
# Processing Record 3 of Set 8 | tasiilaq
# Processing Record 4 of Set 8 | vanavara
# Processing Record 5 of Set 8 | saint george
# Processing Record 6 of Set 8 | manggar
# Processing Record 7 of Set 8 | peniche
# Processing Record 8 of Set 8 | tigil
# Processing Record 9 of Set 8 | ostrovnoy
# Processing Record 10 of Set 8 | mao
# Processing Record 11 of Set 8 | atar
# Processing Record 12 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 8 | sibolga
# Processing Record 14 of Set 8 | ishikari
# Processing Record 15 of Set 8 | fort nelson
# Processing Record 16 of Set 8 | buala
# Processing Record 17 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 8 | vestmannaeyjar
# Processing Record 19 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 8 | skibbereen
# Processing Record 21 of Set 8 | byron bay
# Processing Record 22 of Set 8 | ibra
# Processing Record 23 of Set 8 | yongan
# Processing Record 24 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 8 | mount isa
# Processing Record 26 of Set 8 | severo-kurilsk
# Processing Record 27 of Set 8 | kang
# Processing Record 28 of Set 8 | hay river
# Processing Record 29 of Set 8 | manokwari
# Processing Record 30 of Set 8 | taltal
# Processing Record 31 of Set 8 | udachnyy
# Processing Record 32 of Set 8 | dingle
# Processing Record 33 of Set 8 | katsuura
# Processing Record 34 of Set 8 | nastola
# Processing Record 35 of Set 8 | necochea
# Processing Record 36 of Set 8 | corralillo
# Processing Record 37 of Set 8 | okhotsk
# Processing Record 38 of Set 8 | pontianak
# Processing Record 39 of Set 8 | jamalpur
# Processing Record 40 of Set 8 | vao
# Processing Record 41 of Set 8 | novyy urgal
# Processing Record 42 of Set 8 | arica
# Processing Record 43 of Set 8 | kajaani
# Processing Record 44 of Set 8 | koumac
# Processing Record 45 of Set 8 | yabelo
# Processing Record 46 of Set 8 | batamshinskiy
# Processing Record 47 of Set 8 | port-cartier
# Processing Record 48 of Set 8 | diamantino
# Processing Record 49 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | soyo
# Processing Record 2 of Set 9 | mandya
# Processing Record 3 of Set 9 | vardo
# Processing Record 4 of Set 9 | santa rita
# Processing Record 5 of Set 9 | casa grande
# Processing Record 6 of Set 9 | simbahan
# Processing Record 7 of Set 9 | conceicao do mato dentro
# Processing Record 8 of Set 9 | tuatapere
# Processing Record 9 of Set 9 | broken hill
# Processing Record 10 of Set 9 | staraya poltavka
# Processing Record 11 of Set 9 | beloha
# Processing Record 12 of Set 9 | amahai
# Processing Record 13 of Set 9 | west monroe
# Processing Record 14 of Set 9 | san ramon de la nueva oran
# Processing Record 15 of Set 9 | linjiang
# Processing Record 16 of Set 9 | senneterre
# Processing Record 17 of Set 9 | pilar
# Processing Record 18 of Set 9 | huai yot
# Processing Record 19 of Set 9 | waipawa
# Processing Record 20 of Set 9 | brae
# Processing Record 21 of Set 9 | sola
# Processing Record 22 of Set 9 | sao joao da barra
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | doaba
# Processing Record 25 of Set 9 | vinh
# Processing Record 26 of Set 9 | luganville
# Processing Record 27 of Set 9 | san patricio
# Processing Record 28 of Set 9 | havre-saint-pierre
# Processing Record 29 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 9 | lima
# Processing Record 32 of Set 9 | yima
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | ranong
# Processing Record 35 of Set 9 | chifeng
# Processing Record 36 of Set 9 | peer
# Processing Record 37 of Set 9 | pires do rio
# Processing Record 38 of Set 9 | batagay
# Processing Record 39 of Set 9 | safford
# Processing Record 40 of Set 9 | korla
# Processing Record 41 of Set 9 | derzhavinsk
# Processing Record 42 of Set 9 | adrar
# Processing Record 43 of Set 9 | uyemskiy
# Processing Record 44 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 9 | kavieng
# Processing Record 46 of Set 9 | bolivar
# Processing Record 47 of Set 9 | tambura
# Processing Record 48 of Set 9 | merauke
# Processing Record 49 of Set 9 | krasnyy chikoy
# Processing Record 50 of Set 9 | lagunas
# Processing Record 1 of Set 10 | olinda
# Processing Record 2 of Set 10 | coahuayana
# Processing Record 3 of Set 10 | maceio
# Processing Record 4 of Set 10 | mercedes
# Processing Record 5 of Set 10 | luanda
# Processing Record 6 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 10 | kalininsk
# Processing Record 8 of Set 10 | camacha
# Processing Record 9 of Set 10 | sitia
# Processing Record 10 of Set 10 | dunedin
# Processing Record 11 of Set 10 | kamenka
# Processing Record 12 of Set 10 | gornyy
# Processing Record 13 of Set 10 | porto novo
# Processing Record 14 of Set 10 | yar-sale
# Processing Record 15 of Set 10 | abnub
# Processing Record 16 of Set 10 | qasigiannguit
# Processing Record 17 of Set 10 | manaure
# Processing Record 18 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 10 | lufilufi
# Processing Record 20 of Set 10 | breza
# Processing Record 21 of Set 10 | calama
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | alegrete
# Processing Record 24 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 10 | sochi
# Processing Record 26 of Set 10 | pevek
# Processing Record 27 of Set 10 | fukue
# Processing Record 28 of Set 10 | cooma
# Processing Record 29 of Set 10 | laguna
# Processing Record 30 of Set 10 | maragogi
# Processing Record 31 of Set 10 | abu samrah
# Processing Record 32 of Set 10 | kilembe
# Processing Record 33 of Set 10 | gusinoye ozero
# Processing Record 34 of Set 10 | pacasmayo
# Processing Record 35 of Set 10 | mpongwe
# Processing Record 36 of Set 10 | nhulunbuy
# Processing Record 37 of Set 10 | obo
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | sioux lookout
# Processing Record 40 of Set 10 | pachino
# Processing Record 41 of Set 10 | kidal
# Processing Record 42 of Set 10 | grand gaube
# Processing Record 43 of Set 10 | partenit
# Processing Record 44 of Set 10 | kostomuksha
# Processing Record 45 of Set 10 | makakilo city
# Processing Record 46 of Set 10 | englehart
# Processing Record 47 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 10 | boende
# Processing Record 49 of Set 10 | vostok
# Processing Record 50 of Set 10 | paso de carrasco
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | cordele
# Processing Record 3 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 11 | zheleznodorozhnyy
# Processing Record 5 of Set 11 | matagami
# Processing Record 6 of Set 11 | dabhol
# Processing Record 7 of Set 11 | aykhal
# Processing Record 8 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 11 | hwange
# Processing Record 10 of Set 11 | bartica
# Processing Record 11 of Set 11 | tagusao
# Processing Record 12 of Set 11 | dunda
# Processing Record 13 of Set 11 | tautira
# Processing Record 14 of Set 11 | grimshaw
# Processing Record 15 of Set 11 | kupang
# Processing Record 16 of Set 11 | klaksvik
# Processing Record 17 of Set 11 | destin
# Processing Record 18 of Set 11 | bonfim
# Processing Record 19 of Set 11 | mattru
# Processing Record 20 of Set 11 | farafangana
# Processing Record 21 of Set 11 | komsomolskiy
# Processing Record 22 of Set 11 | zitlala
# Processing Record 23 of Set 11 | barguzin
# Processing Record 24 of Set 11 | yeppoon
# Processing Record 25 of Set 11 | belmonte
# Processing Record 26 of Set 11 | victoria point
# Processing Record 27 of Set 11 | kyshtovka
# Processing Record 28 of Set 11 | pitimbu
# Processing Record 29 of Set 11 | allentown
# Processing Record 30 of Set 11 | mayumba
# Processing Record 31 of Set 11 | umm lajj
# Processing Record 32 of Set 11 | itaituba
# Processing Record 33 of Set 11 | kirakira
# Processing Record 34 of Set 11 | nouakchott
# Processing Record 35 of Set 11 | glens falls
# Processing Record 36 of Set 11 | komatsushima
# Processing Record 37 of Set 11 | zuya
# Processing Record 38 of Set 11 | harper
# Processing Record 39 of Set 11 | ankazobe
# Processing Record 40 of Set 11 | southbridge
# Processing Record 41 of Set 11 | surovikino
# Processing Record 42 of Set 11 | vaitape
# Processing Record 43 of Set 11 | ramsar
# Processing Record 44 of Set 11 | urusha
# Processing Record 45 of Set 11 | slave lake
# Processing Record 46 of Set 11 | codrington
# Processing Record 47 of Set 11 | inuvik
# Processing Record 48 of Set 11 | tarakan
# Processing Record 49 of Set 11 | zaraza
# Processing Record 50 of Set 11 | isangel
# Processing Record 1 of Set 12 | guanica
# Processing Record 2 of Set 12 | nantucket
# Processing Record 3 of Set 12 | chkalovskoye
# Processing Record 4 of Set 12 | kudahuvadhoo
# Processing Record 5 of Set 12 | harwich
# Processing Record 6 of Set 12 | gweta
# Processing Record 7 of Set 12 | altamirano
# Processing Record 8 of Set 12 | malangali
# Processing Record 9 of Set 12 | alfenas
# Processing Record 10 of Set 12 | liverpool
# Processing Record 11 of Set 12 | verkhnevilyuysk
# Processing Record 12 of Set 12 | sovetskiy
# Processing Record 13 of Set 12 | tabuk
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | serpa
# Processing Record 16 of Set 12 | isparta
# Processing Record 17 of Set 12 | amarante do maranhao
# Processing Record 18 of Set 12 | bera
# Processing Record 19 of Set 12 | miri
# Processing Record 20 of Set 12 | davila
# Processing Record 21 of Set 12 | natal
# Processing Record 22 of Set 12 | toropets
# Processing Record 23 of Set 12 | muros
# Processing Record 24 of Set 12 | asfi
# Processing Record 25 of Set 12 | gat
# Processing Record 26 of Set 12 | weligama
# Processing Record 27 of Set 12 | maitland
# Processing Record 28 of Set 12 | ciudad guayana
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | sept-iles
# Processing Record 31 of Set 12 | salym
# Processing Record 32 of Set 12 | qaqortoq
# Processing Record 33 of Set 12 | morehead
# Processing Record 34 of Set 12 | mgandu
# Processing Record 35 of Set 12 | ferrol
# Processing Record 36 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 12 | chau doc
# Processing Record 38 of Set 12 | coquimbo
# Processing Record 39 of Set 12 | ca mau
# Processing Record 40 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 12 | moshenskoye
# Processing Record 42 of Set 12 | kiruna
# Processing Record 43 of Set 12 | taitung
# Processing Record 44 of Set 12 | porto walter
# Processing Record 45 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 46 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 12 | lysva
# Processing Record 48 of Set 12 | gondar
# Processing Record 49 of Set 12 | sarakhs
# Processing Record 50 of Set 12 | opuwo
# Processing Record 1 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 13 | kieta
# Processing Record 3 of Set 13 | agadez
# Processing Record 4 of Set 13 | vidim
# Processing Record 5 of Set 13 | miajadas
# Processing Record 6 of Set 13 | ahipara
# Processing Record 7 of Set 13 | rabo de peixe
# Processing Record 8 of Set 13 | dalvik
# Processing Record 9 of Set 13 | lae
# Processing Record 10 of Set 13 | tateyama
# Processing Record 11 of Set 13 | aklavik
# Processing Record 12 of Set 13 | lata
# Processing Record 13 of Set 13 | margate
# Processing Record 14 of Set 13 | meadow lake
# Processing Record 15 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | cartagena
# Processing Record 17 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 18 of Set 13 | kokopo
# Processing Record 19 of Set 13 | price
# Processing Record 20 of Set 13 | sharan
# Processing Record 21 of Set 13 | jacareacanga
# Processing Record 22 of Set 13 | smithers
# Processing Record 23 of Set 13 | bathsheba
# Processing Record 24 of Set 13 | tabou
# Processing Record 25 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 13 | imbituba
# Processing Record 27 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 28 of Set 13 | yei
# Processing Record 29 of Set 13 | hervey bay
# Processing Record 30 of Set 13 | kitami
# Processing Record 31 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 13 | kaberamaido
# Processing Record 33 of Set 13 | bismarck
# Processing Record 34 of Set 13 | katangli
# Processing Record 35 of Set 13 | konstantinovka
# Processing Record 36 of Set 13 | nome
# Processing Record 37 of Set 13 | badvel
# Processing Record 38 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 13 | inta
# Processing Record 41 of Set 13 | san pedro
# Processing Record 42 of Set 13 | la asuncion
# Processing Record 43 of Set 13 | pangody
# Processing Record 44 of Set 13 | samoylovka
# Processing Record 45 of Set 13 | rancho palos verdes
# Processing Record 46 of Set 13 | abay
# Processing Record 47 of Set 13 | sydney
# Processing Record 48 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 13 | yamada
# Processing Record 50 of Set 13 | songea
# Processing Record 1 of Set 14 | port hawkesbury
# Processing Record 2 of Set 14 | tungor
# Processing Record 3 of Set 14 | da nang
# Processing Record 4 of Set 14 | tombouctou
# Processing Record 5 of Set 14 | pundaguitan
# Processing Record 6 of Set 14 | bitkine
# Processing Record 7 of Set 14 | constitucion
# Processing Record 8 of Set 14 | neryungri
# Processing Record 9 of Set 14 | tilichiki
# Processing Record 10 of Set 14 | dubinino
# Processing Record 11 of Set 14 | wilmington
# Processing Record 12 of Set 14 | bud
# Processing Record 13 of Set 14 | metro
# Processing Record 14 of Set 14 | sao miguel do araguaia
# Processing Record 15 of Set 14 | pa sang
# Processing Record 16 of Set 14 | palauig
# Processing Record 17 of Set 14 | xining
# Processing Record 18 of Set 14 | ranchi
# Processing Record 19 of Set 14 | henties bay
# Processing Record 20 of Set 14 | orlik
# Processing Record 21 of Set 14 | japura
# Processing Record 22 of Set 14 | marawi
# Processing Record 23 of Set 14 | xiaoweizhai
# Processing Record 24 of Set 14 | voi
# Processing Record 25 of Set 14 | kasane
# Processing Record 26 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 14 | machico
# Processing Record 28 of Set 14 | kankakee
# Processing Record 29 of Set 14 | high level
# Processing Record 30 of Set 14 | robertsport
# Processing Record 31 of Set 14 | barcelos
# Processing Record 32 of Set 14 | sicamous
# Processing Record 33 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 14 | havelock
# Processing Record 35 of Set 14 | banfora
# Processing Record 36 of Set 14 | port augusta
# Processing Record 37 of Set 14 | palana
# Processing Record 38 of Set 14 | aljezur
# Processing Record 39 of Set 14 | mosetse
# Processing Record 40 of Set 14 | lodja
# Processing Record 41 of Set 14 | marovoay
# Processing Record 42 of Set 14 | tyukalinsk
# Processing Record 43 of Set 14 | pouembout
# Processing Record 44 of Set 14 | baiyin
# Processing Record 45 of Set 14 | rudnaya pristan
# Processing Record 46 of Set 14 | manzil tamim
# City not found. Skipping...
# Processing Record 47 of Set 14 | kutum
# Processing Record 48 of Set 14 | vershino-darasunskiy
# Processing Record 49 of Set 14 | jiwani
# Processing Record 50 of Set 14 | linxia
# Processing Record 1 of Set 15 | dalgopol
# Processing Record 2 of Set 15 | port hedland
# Processing Record 3 of Set 15 | grand bend
# Processing Record 4 of Set 15 | redcar
# Processing Record 5 of Set 15 | halifax
# Processing Record 6 of Set 15 | mulege
# Processing Record 7 of Set 15 | kristiinankaupunki
# Processing Record 8 of Set 15 | gizo
# Processing Record 9 of Set 15 | sobolevo
# Processing Record 10 of Set 15 | darab
# Processing Record 11 of Set 15 | turkistan
# Processing Record 12 of Set 15 | san-pedro
# Processing Record 13 of Set 15 | bilibino
# Processing Record 14 of Set 15 | mohan
# Processing Record 15 of Set 15 | finschhafen
# Processing Record 16 of Set 15 | talcahuano
# Processing Record 17 of Set 15 | mishan
# Processing Record 18 of Set 15 | hauterive
# Processing Record 19 of Set 15 | tripoli
# Processing Record 20 of Set 15 | trairi
# Processing Record 21 of Set 15 | bankura
# Processing Record 22 of Set 15 | villacarrillo
# Processing Record 23 of Set 15 | seoul
# Processing Record 24 of Set 15 | kapuskasing
# Processing Record 25 of Set 15 | bairiki
# Processing Record 26 of Set 15 | helena
# Processing Record 27 of Set 15 | alta gracia
# Processing Record 28 of Set 15 | puruaran
# Processing Record 29 of Set 15 | mantua
# Processing Record 30 of Set 15 | horsham
# Processing Record 31 of Set 15 | rosario
# Processing Record 32 of Set 15 | puerto madero
# Processing Record 33 of Set 15 | pak phanang
# Processing Record 34 of Set 15 | lompoc
# Processing Record 35 of Set 15 | abrau-dyurso
# Processing Record 36 of Set 15 | morant bay
# Processing Record 37 of Set 15 | fort-shevchenko
# Processing Record 38 of Set 15 | xinzhou
# Processing Record 39 of Set 15 | santiago del estero
# Processing Record 40 of Set 15 | uray
# Processing Record 41 of Set 15 | maniitsoq
# Processing Record 42 of Set 15 | zyryanka
# Processing Record 43 of Set 15 | turukhansk
# Processing Record 44 of Set 15 | kayanga
# Processing Record 45 of Set 15 | chom bung
# City not found. Skipping...
# Processing Record 46 of Set 15 | caxito
# Processing Record 47 of Set 15 | letlhakane
# Processing Record 48 of Set 15 | providencia
# Processing Record 49 of Set 15 | ucluelet
# Processing Record 50 of Set 15 | manta
# Processing Record 1 of Set 16 | kamyshin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ketchikan      US  55.3422 -131.6461     41.47        87          40
# 1  Saint-Philippe      RE -21.3585   55.7679     78.39        89          79
# 2          Gumdag      TM  39.2061   54.5906     49.01        55         100
# 3          Torbay      CA  47.6666  -52.7314     35.28        90         100
# 4      Winnemucca      US  40.9730 -117.7357     55.45        28           0
# 5   Cockburn Town      TC  21.4612  -71.1419     82.36        54          40
# 6    Punta Arenas      CL -53.1500  -70.9167     51.91        59          75
# 7        Kadnikov      RU  59.5022   40.3380     28.87        94         100
# 8           Salmo      CA  49.1999 -117.2689     41.07        86         100
# 9          Avarua      CK -21.2078 -159.7750     82.45        78         100
#
#    Wind Speed Current Description
# 0        6.91    scattered clouds
# 1       13.27       moderate rain
# 2       16.28     overcast clouds
# 3       25.32                mist
# 4        6.91           clear sky
# 5       19.57    scattered clouds
# 6       20.71       broken clouds
# 7        3.91     overcast clouds
# 8        3.58     overcast clouds
# 9        5.75     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
